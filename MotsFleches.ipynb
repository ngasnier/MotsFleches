# %%
# %load_ext autoreload
# %autoreload
from MotsFleches import *
import random

# %%
import unittest
from tests import *


# Exécute les tests dans le notebook
suite = unittest.TestSuite()
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestDictionary))
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestIPossible))
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGrid))
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGenerator))
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_Add (tests.test_Dictionary.TestDictionary.test_Add) ... ok
# test_Count (tests.test_Dictionary.TestDictionary.test_Count) ... ok
# test_Insersect (tests.test_Dictionary.TestDictionary.test_Insersect) ... ok
# test_Remove (tests.test_Dictionary.TestDictionary.test_Remove) ... ok
# test_SetLetter (tests.test_Dictionary.TestDictionary.test_SetLetter) ... ok
# test_Str (tests.test_Dictionary.TestDictionary.test_Str) ... ok
# test_findCandidates1 (tests.test_Dictionary.TestDictionary.test_findCandidates1) ... ok
# test_findCandidates2 (tests.test_Dictionary.TestDictionary.test_findCandidates2) ... ok
# test_findCandidates3 (tests.test_Dictionary.TestDictionary.test_findCandidates3) ... ok
# test_findCandidates4 (tests.test_Dictionary.TestDictionary.test_findCandidates4) ... ok
# test_findCandidates5 (tests.test_Dictionary.TestDictionary.test_findCandidates5) ... ok
# test_initialization (tests.test_Dictionary.TestDictionary.test_initialization) ... ok
# testSplitInterval (tests.test_IPossible.TestIPossible.testSplitInterval) ... ok
# test_AllWords (tests.test_IPossible.TestIPossible.test_AllWords) ... ok
# test_PossibleSet (tests.test_IPossible.TestIPossible.test_PossibleSet) ... ok
# test_compareTo (tests.test_CrosswordGrid.TestCrosswordGrid.test_compareTo) ... ok
# test_findContainingIntervalIdx (tests.test_CrosswordGrid.TestCrosswordGrid.test_findContainingIntervalIdx) ... ok
# test_findNextInterval (tests.test_CrosswordGrid.TestCrosswordGrid.test_findNextInterval) ... ok
# test_getIntervalContent_horizontal (tests.test_CrosswordGrid.TestCrosswordGrid.test_getIntervalContent_horizontal) ... ok
# test_getIntervalContent_vertical (tests.test_CrosswordGrid.TestCrosswordGrid.test_getIntervalContent_vertical) ... ok
# test_initialization (tests.test_CrosswordGrid.TestCrosswordGrid.test_initialization) ... ok
# test_isGridComplete (tests.test_CrosswordGrid.TestCrosswordGrid.test_isGridComplete) ... ok
# test_placeWord_horizontal (tests.test_CrosswordGrid.TestCrosswordGrid.test_placeWord_horizontal) ... ok
# test_placeWord_vertical (tests.test_CrosswordGrid.TestCrosswordGrid.test_placeWord_vertical) ... ok
# test_put (tests.test_CrosswordGrid.TestCrosswordGrid.test_put) ... ok
# test_setGridContent (tests.test_CrosswordGrid.TestCrosswordGrid.test_setGridContent) ... ok
# test_splitInterval (tests.test_CrosswordGrid.TestCrosswordGrid.test_splitInterval) ... ok
# test_toString (tests.test_CrosswordGrid.TestCrosswordGrid.test_toString) ... ok
# test_isValid_definitionRules (tests.test_CrosswordGenerator.TestCrosswordGenerator.test_isValid_definitionRules) ... ok
# test_isValid_empty (tests.test_CrosswordGenerator.TestCrosswordGenerator.test_isValid_empty) ... ok
# test_isValid_intermediate (tests.test_CrosswordGenerator.TestCrosswordGenerator.test_isValid_intermediate) ... ok
# test_isValid_isolatedCell (tests.test_CrosswordGenerator.TestCrosswordGenerator.test_isValid_isolatedCell) ... ok
#
# ----------------------------------------------------------------------
# Ran 32 tests in 0.382s
#
# OK
# <unittest.runner.TextTestResult run=32 errors=0 failures=0>

# %%
random.seed(224628)
print("loading...")
#dico = Dictionary("dict/liste_francais.txt") # "liste_francais.txt"
dico = Dictionary("dict/test1.txt")

Dictionary.initInstance(dico)

print("generating...")
generator = CrosswordGenerator(dico)

grid = generator.generateGrid(6, 7) # 9 x 11
if (grid is not None):
    print(grid)
else:
    print("Generation failed")

print("Nb lookups : ", dico.nbLookups)
print("Nb cache miss : ", dico.nbCacheMiss)
# Out:
# loading...
# generating...
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [PossibleSet([(1, 0, 6, True)]), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(1, 0, 6, True)])
# [Allwords(6, [LASERS,TOLIER])]
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [Allwords(6, [LASERS,TOLIER]), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  Allwords(6, [LASERS,TOLIER])
# [SetWord(LASERS)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [Allwords(6, [LASERS]), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  Allwords(6, [LASERS])
# [SetWord(LASERS)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 1)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 1), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 0)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 0), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 1), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 0)
# [PossibleSet([(2, 2, 6, True)])]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 4), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 1), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 4)
# [Allwords(4, [SALE])]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 2)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 1), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 2)
# [Allwords(2, [EN,PI]), PossibleSet([(2, 4, 6, True)])]
# place definition Allwords(2, [EN,PI]) 3
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 3)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 3), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 1), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 3)
# [Allwords(3, [NET,EPI,REE]), PossibleSet([(2, 5, 6, True)])]
# place definition Allwords(3, [NET,EPI,REE]) 4
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 2)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 2)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 2)
# [Allwords(2, [EN,PI]), PossibleSet([(2, 4, 6, True)])]
# place definition Allwords(2, [EN,PI]) 3
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 3)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 3), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 3)
# [Allwords(3, [NET,EPI,REE]), PossibleSet([(2, 5, 6, True)])]
# place definition Allwords(3, [NET,EPI,REE]) 4
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 4), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 4)
# [Allwords(4, [SALE])]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 2)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 4)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 4), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 4)
# [Allwords(4, [SALE])]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# [SplitInterval([(2, 1, 6, True)], 4)]
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 2)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 3)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 3), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 3)
# [Allwords(3, [NET,EPI,REE]), PossibleSet([(2, 5, 6, True)])]
# place definition Allwords(3, [NET,EPI,REE]) 4
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 4), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 2), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 4)
# [Allwords(4, [SALE])]
# <- backtracking
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 3)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 3), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  PossibleSet([(2, 1, 6, True)])
# [SplitInterval([(2, 1, 6, True)], 4)]
# * * *
# LASERS
# *
#
# *
#
# *
#
# hIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 4), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [SetWord(LASERS), SplitInterval([(2, 1, 6, True)], 3), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(2, 1, 6, True)], 4)
# [Allwords(4, [SALE])]
# <- backtracking
# <- backtracking
# [SplitInterval([(2, 1, 6, True)], 4)]
# <- backtracking
# <- backtracking
# [SetWord(TOLIER)]
# <- backtracking
# [SplitInterval([(1, 0, 6, True)], 2)]
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [SplitInterval([(1, 0, 6, True)], 2), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(1, 0, 6, True)], 2)
# [Allwords(2, [EN,PI]), PossibleSet([(1, 3, 6, True)])]
# place definition Allwords(2, [EN,PI]) 2
# <- backtracking
# [SplitInterval([(1, 0, 6, True)], 3)]
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [SplitInterval([(1, 0, 6, True)], 3), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(1, 0, 6, True)], 3)
# [Allwords(3, [NET,EPI,REE]), PossibleSet([(1, 4, 6, True)])]
# place definition Allwords(3, [NET,EPI,REE]) 3
# <- backtracking
# [SplitInterval([(1, 0, 6, True)], 2)]
# [SplitInterval([(1, 0, 6, True)], 4)]
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [SplitInterval([(1, 0, 6, True)], 4), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(1, 0, 6, True)], 4)
# [Allwords(4, [SALE]), PossibleSet([(1, 5, 6, True)])]
# place definition Allwords(4, [SALE]) 4
# <- backtracking
# [SplitInterval([(1, 0, 6, True)], 5)]
# * * *
#
# *
#
# *
#
# *
#
# hIntervals :  [SplitInterval([(1, 0, 6, True)], 5), PossibleSet([(2, 1, 6, True)]), PossibleSet([(3, 0, 6, True)]), PossibleSet([(4, 1, 6, True)]), PossibleSet([(5, 0, 6, True)]), PossibleSet([(6, 1, 6, True)])]
# vIntervals :  [PossibleSet([(1, 0, 7, False)]), PossibleSet([(2, 1, 7, False)]), PossibleSet([(3, 0, 7, False)]), PossibleSet([(4, 1, 7, False)]), PossibleSet([(5, 0, 7, False)])]
# Possible for choices :  SplitInterval([(1, 0, 6, True)], 5)
# [Allwords(5, [RASEE,EPRIS])]
# <- backtracking
# [SplitInterval([(1, 0, 6, True)], 5)]
# <- backtracking
# Generation failed
# Nb lookups :  7240
# Nb cache miss :  35

# %%
# Check initialisation 
dict = Dictionary("dict/test1.txt")
Dictionary.initInstance(dict)
generator = CrosswordGenerator(dict)
grid = CrosswordGrid(6, 7)
generator.initGridTemplate(grid)
interval = Interval(1, 0, 2, True)
possibles = PossibleSet(interval)
possibles.filter(grid.content, grid.usedWords)
print(possibles.count, 1)

# Check methods
grid.placeWord("BARONNE", grid.vIntervals[0], False)
interval = grid.hIntervals[0]
possibles = PossibleSet(interval)
possibles.filter(grid.content, grid.usedWords)
print(possibles.count, 7)
# Out:
# 1 1
# 7 4

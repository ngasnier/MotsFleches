# %%
# %load_ext autoreload
# %autoreload
from MotsFleches import Dictionary
from MotsFleches import CrosswordGenerator
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import unittest
from tests import *


# Exécute les tests dans le notebook
suite = unittest.TestSuite()
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestDictionary))
#suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestIPossible))
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGrid))
suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGenerator))
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       6 suite = unittest.TestSuite()
#       7 suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestDictionary))
# ----> 8 suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestIPossible))
#       9 suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGrid))
#      10 suite.addTest(unittest.TestLoader().loadTestsFromTestCase(TestCrosswordGenerator))
#
# NameError: name 'TestIPossible' is not defined

# %%
random.seed()
print("loading...")
dico = Dictionary("dict/liste_francais.txt") # "liste_francais.txt"

print("generating...")
generator = CrosswordGenerator(dico)

grid = generator.generateGrid(6, 7) # 9 x 11
if (grid is not None):
    print(grid)
else:
    print("Generation failed")

print("Nb lookups : ", dico.nbLookups)
print("Nb cache miss : ", dico.nbCacheMiss)
# Out:
# loading...
# generating...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 8
#       5 print("generating...")
#       6 generator = CrosswordGenerator(dico)
# ----> 8 grid = generator.generateGrid(9, 11) # 9 x 11
#       9 if (grid is not None):
#      10     print(grid)
#
# File ~/Projects/Mots-Fleches/MotsFleches/CrosswordGenerator.py:17, in CrosswordGenerator.generateGrid(self, width, height)
#      15 def generateGrid(self, width:int, height:int):
#      16     grid = CrosswordGrid(width, height)
# ---> 17     return self.fillGrid(grid)
#
# File ~/Projects/Mots-Fleches/MotsFleches/CrosswordGenerator.py:52, in CrosswordGenerator.fillGrid(self, grid)
#      48 newGrid.placeWord(word, interval)
#      50 if self.isGridValid(newGrid):
#      51     # Fill recursively alternating horizontal and vertical filling
# ---> 52     newGrid = self.fillGrid(newGrid)
#      53 else:
#      54     newGrid = None
#
# File ~/Projects/Mots-Fleches/MotsFleches/CrosswordGenerator.py:50, in CrosswordGenerator.fillGrid(self, grid)
#      47 newGrid = copy.deepcopy(grid)
#      48 newGrid.placeWord(word, interval)
# ---> 50 if self.isGridValid(newGrid):
#      51     # Fill recursively alternating horizontal and vertical filling
#      52     newGrid = self.fillGrid(newGrid)
#      53 else:
#
# File ~/Projects/Mots-Fleches/MotsFleches/CrosswordGenerator.py:63, in CrosswordGenerator.isGridValid(self, grid)
#      61 for interval in grid.hIntervals:
#      62     intervalContent = grid.getIntervalContent(interval)
# ---> 63     candidates = self.dict.findCandidates(''.join(intervalContent), grid.usedWords)
#      64     if len(candidates)==0:
#      65         return False
#
# File ~/Projects/Mots-Fleches/MotsFleches/Dictionary.py:269, in Dictionary.findCandidates(self, placeholder, exclusions, exactLength)
#     267             words = list(filter(regexp.match, bestResult))
#     268             cache[subPattern] = words
# --> 269         candidates = candidates + [w for w in words if w not in exclusions and w not in candidates]
#     270 return candidates
#
# KeyboardInterrupt:
